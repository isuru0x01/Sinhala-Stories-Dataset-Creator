ා කරා. මගෙන් ඇහුව කොහෙද යන්නෙ කියලා. මම අත්තටම හිටියෙ එදා ක්ලාස් කට් කරලා. අපේ උන් ටික එන්න පරක්කු වෙනවා කිව්ව නිසා එතන හිටියේ. මම කිව්වා ක්ලස් ගියේ නෑ කියලා. පොරට තේරුනා මම කට් කරල ඉන්නෙ කියලා. පොර කීව වැඩිය මෙතන ඉන්න එපා පොලිසියෙන් එනවා කියලා. මල්ලි ස්ටේශ්න් එකෙ අනිත් කෑල්ලට යන්න කියලා. එන්න මාත් ඒකට යනව කිව්වා. මාත් පොර එක්ක ඒ පැත්තට ගියා. ඒ පැත්තෙ කවුරුත් නෑ.ගියාම පොර හොදටම ලගට ඇවිත් අහනවා මල්ලි ලස්සනයි යමුද ෆිල්ම් එකක් බලන්න කියලා. මට තේරුනා මු දැන් සීන් එකට එන්න හදන්නෙ කියලා. මට බයත් හිතුනා. එත් සෙට් වෙලා නැති නිසා ආසත් හිතුනා. මම අහුව කොහෙද කියලා. පොර කිව්වා කොටුවෙ කියලා. රියො එක කියල තියෙන්නෙ මම දන්නෙ නෑ. ඒක ගේ සීන් එකේ අය සෙට් වෙන තනක් කියල. මම කිව්ව එච්චර එහේ යන්න බෑ කියල. පොරට තේරුනා මම වැඩේට කැමතියි කියල. එහෙනම් මල්ලි අපි ගල්කිස්සෙ බිච් යමුද  ...

# %%
# View first few rows
for i, story in enumerate(dataset['train']['story'][:3]):
    print(f"\n--- Story {i+1} ---")
    print(story[:200])  # Print first 200 characters

print("\n" + "="*50 + "\n")
# Out:
# --- Story 1 ---
# ත්‍රීවිල් අන්කල්   මම වරකාපොල අපි එහෙට ආවෙ කුලියට. ඉතිං අපි අලුත් හින්දා මෙහෙ අයව දන්නෑ. මම දවසක් ක්ලාස් යනකොට ත්‍රීවිල් එකක් නවත්තලා කිව්වා මල්ලි ටවුමටද යන්නෙ මන් ඇරලවන්නම් කියල. ඉතිං මටත් අමාරු නිසා
#
# --- Story 2 ---
# මේක උනේ 2018 වගේ. මට එතකොට වයස 21 කොලු සීන් එකට පොඩ්ඩක් ආසාවක් තිබුනා. ඒත් සෙට් වෙලා තිබුනෙ නෑ. මම දවසක් පානදුර ස්ටේශන් එකේ ඉන්න කොට වයස 50ක විතර අන්කල් කෙනෙක් කැරකෙනව වගෙ හිතුනා. පොර මගෙ දිහා බල්න් ඉ
#
# --- Story 3 ---
# ඒ දවස්වල හරියට පෑවිල්ල නිතර නිතර වතුර කපනවා. නාන්න ගියේ වැවට ඒ දවස් ටිකේ යනකොට යන්නේ ගෙදර අයියලා එක්ක. ඒ යද්දී නිතර පාහේ කලුම කලු කොල්ලෙක් කොයි වෙලේ බැලුවත් ඇදන් ඉන්නෙ සරම කොට කරගෙන උඩට මුකුත් නැතුව.
#
# ==================================================

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['story'],
#         num_rows: 465
#     })
# })

# %%
dataset2 = load_dataset("polyglots/MADLAD_CulturaX_cleaned")
# Out:
# {'text': ['ආණ්ඩුව පටන් ගත් වහා\u2009ම ආණ්ඩුවෙන් බේරීමට පොලිස් පරීක්ෂක නිශාන්ත සිල්වා රට හැර ගියේ\u2009ය.', 'එනිසාම ශානි විසින් කරනු ලැබූ මෙහෙයුම් හා පරීක්ෂණ අපි මෙසේ පළ කරමු.', 'ඉන්\u2009පසු මඩකලපුව මොරොක්කොට්ටන්චේන, මහිලඩතිව්, කොක්කඩිචෝලෙයි, වැල්ලවාඩිය, යාලබෝව, සංගමන්කන්ද, ශාස්ත්\u200dරවෙල්ලි යන කඳවුරුවල සේවය කොට විශේෂ ප්\u200dරභූ ආරක්ෂක පාඨමාලාව සාර්ථකව හැදෑරීම හේතුවෙන් ප්\u200dරභූ ආරක්ෂක රාජකාරි සඳහා වෝඞ් පෙදෙස විශේෂ කාර්ය බළකාය කඳවුරට අනුයක්ත කරන ලදී.'], 'lang': ['si', 'si', 'si'], 'src': ['CulturaX', 'CulturaX', 'CulturaX']}

# %%
print(dataset2)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'lang', 'src'],
#         num_rows: 10730154
#     })
# })

# %%
# View first few rows
for i, story in enumerate(dataset2['train']['text'][:3]):
    print(f"\n--- Story {i+1} ---")
    print(story[:])

print("\n" + "="*50 + "\n")
# Out:
# --- Story 1 ---
# ආණ්ඩුව පටන් ගත් වහා ම ආණ්ඩුවෙන් බේරීමට පොලිස් පරීක්ෂක නිශාන්ත සිල්වා රට හැර ගියේ ය.
#
# --- Story 2 ---
# එනිසාම ශානි විසින් කරනු ලැබූ මෙහෙයුම් හා පරීක්ෂණ අපි මෙසේ පළ කරමු.
#
# --- Story 3 ---
# ඉන් පසු මඩකලපුව මොරොක්කොට්ටන්චේන, මහිලඩතිව්, කොක්කඩිචෝලෙයි, වැල්ලවාඩිය, යාලබෝව, සංගමන්කන්ද, ශාස්ත්‍රවෙල්ලි යන කඳවුරුවල සේවය කොට විශේෂ ප්‍රභූ ආරක්ෂක පාඨමාලාව සාර්ථකව හැදෑරීම හේතුවෙන් ප්‍රභූ ආරක්ෂක රාජකාරි සඳහා වෝඞ් පෙදෙස විශේෂ කාර්ය බළකාය කඳවුරට අනුයක්ත කරන ලදී.
#
# ==================================================

# %%
from datasets import load_dataset, Dataset, DatasetDict, concatenate_datasets

# Rename 'text' to 'story' and concatenate
# This creates a new dataset with only the 'story' column
dataset2_renamed = dataset2['train'].rename_column('text', 'story')
dataset2_story_only = dataset2_renamed.remove_columns(['lang', 'src'])

# Concatenate the datasets
combined_dataset = concatenate_datasets([dataset['train'], dataset2_story_only])

print(f"Combined dataset rows: {len(combined_dataset)}")
print(f"Combined dataset features: {combined_dataset.features}")
print(f"\nFirst row from dataset1: {combined_dataset[0]['story'][:100]}...")
print(f"\nLast row from dataset2: {combined_dataset[-1]['story'][:100]}...")

# Save the combined dataset
combined_dataset_dict = DatasetDict({'train': combined_dataset})
print(f"\nFinal structure:")
print(combined_dataset_dict)
# Out:
# Combined dataset rows: 10730619
# Combined dataset features: {'story': Value('string')}
#
# First row from dataset1: ත්‍රීවිල් අන්කල්   මම වරකාපොල අපි එහෙට ආවෙ කුලියට. ඉතිං අපි අලුත් හින්දා මෙහෙ අයව දන්නෑ. මම දවසක් ක්...
#
# Last row from dataset2: අවසාන ‘හේබයාස් කෝපුස්’ ආඥාව එයයි: ඔහුගේ සිරුර - මේ කාරණාවේදී නම් ජීවතුන් අතර සිටින ඔහුගේ සිරුර ඉදිරි...
#
# Final structure:
# DatasetDict({
#     train: Dataset({
#         features: ['story'],
#         num_rows: 10730619
#     })
# })

# %%
# Save the combined dataset
combined_dataset_dict = DatasetDict({'train': combined_dataset})
print(f"\nFinal structure:")
print(combined_dataset_dict)
# Out:
# Final structure:
# DatasetDict({
#     train: Dataset({
#         features: ['story'],
#         num_rows: 10730619
#     })
# })

# %%
# Save to disk (backup)
combined_dataset_dict.save_to_disk("./combined_sinhala_dataset")
# Out:
# Saving the dataset (0/7 shards):   0%|          | 0/10730619 [00:00<?, ? examples/s]

# %%
# Login to Hugging Face (you'll need your token)
from huggingface_hub import login

# %%
# Method 1: Login interactively (recommended for first time)
# login()  # This will prompt you to enter your token

# Method 2: Login with token directly
login(token="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")

# %%
# Push to Hugging Face Hub (this will update the existing dataset)
combined_dataset_dict.push_to_hub(
    "Isuru0x01/sinhala_stories",
    private=False  # Set to True if you want it private
)

print("\n✅ Dataset successfully uploaded to Hugging Face!")
print("URL: https://huggingface.co/datasets/Isuru0x01/sinhala_stories")

print("\n" + "="*50 + "\n")
# Out:
# Uploading the dataset shards:   0%|          | 0/7 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :  10%|9         | 19.9MB /  203MB
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   2%|1         | 3.67MB /  200MB
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   3%|2         | 5.77MB /  201MB
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   3%|2         | 5.77MB /  201MB
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   5%|4         | 9.44MB /  201MB
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   3%|3         | 5.77MB /  187MB
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   3%|2         | 4.19MB /  161MB
# ✅ Dataset successfully uploaded to Hugging Face!
# URL: https://huggingface.co/datasets/Isuru0x01/sinhala_stories
#
# ==================================================

# %%
# ===== STEP 1: Install and setup =====
# !pip install -q datasets huggingface_hub tqdm

import os
import gc
os.environ['HF_DATASETS_CACHE'] = '/content/hf_cache'
gc.enable()

from datasets import load_dataset, Dataset, DatasetDict
from huggingface_hub import login
import hashlib
from tqdm.auto import tqdm

# %%
# ===== STEP 3: Login to Hugging Face =====
# You'll be prompted to enter your token
#login()

# Alternative: Provide token directly
login(token="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")

# %%
# ===== STEP 3: Configuration =====
DATASET_REPO = "Isuru0x01/sinhala_stories"
COMMIT_HASH = "c5cf62d48169879b701ba18b79779545edefa93e"
CHUNK_SIZE = 5000  # Process in smaller chunks

print(f"📦 Dataset: {DATASET_REPO}")
print(f"🔖 Target commit: {COMMIT_HASH}")
print("="*60)
# Out:
# 📦 Dataset: Isuru0x01/sinhala_stories
# 🔖 Target commit: c5cf62d48169879b701ba18b79779545edefa93e
# ============================================================

# %%
# ===== STEP 4: Load datasets with streaming (ultra low memory) =====
print("\n📥 Loading datasets in streaming mode...")

# Option 1: Use streaming mode (doesn't load entire dataset into RAM)
old_dataset_stream = load_dataset(
    DATASET_REPO,
    split="train",
    revision=COMMIT_HASH,
    streaming=True  # This loads data on-the-fly
)

current_dataset_stream = load_dataset(
    DATASET_REPO,
    split="train",
    streaming=True
)

print("✅ Datasets loaded in streaming mode (minimal RAM usage)")
# Out:
# 📥 Loading datasets in streaming mode...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ✅ Datasets loaded in streaming mode (minimal RAM usage)

# %%
# ===== STEP 5: Build hash set from current dataset (in chunks) =====
print("\n🔄 Building hash index from current dataset...")
current_hashes = set()

for i, example in enumerate(tqdm(current_dataset_stream, desc="Indexing current")):
    story_hash = hashlib.md5(example['story'][:200].encode('utf-8')).hexdigest()
    current_hashes.add(story_hash)

    # Periodic garbage collection
    if i % 50000 == 0 and i > 0:
        gc.collect()

print(f"✅ Indexed {len(current_hashes):,} stories from current dataset")
# Out:
# 🔄 Building hash index from current dataset...
# Indexing current: 0it [00:00, ?it/s]
# ✅ Indexed 2 stories from current dataset

# %%
# ===== STEP 6: Filter and save unique stories to disk (chunk by chunk) =====
print("\n📝 Finding unique stories from old dataset...")

import tempfile
import json

# Create temporary file to store unique stories
temp_file = tempfile.NamedTemporaryFile(mode='w', delete=False, suffix='.jsonl')
unique_count = 0
duplicate_count = 0

print(f"💾 Saving unique stories to: {temp_file.name}")

for i, example in enumerate(tqdm(old_dataset_stream, desc="Processing old dataset")):
    story = example['story']
    story_hash = hashlib.md5(story[:200].encode('utf-8')).hexdigest()

    if story_hash not in current_hashes:
        # Write to temporary file (streaming write - no RAM buildup)
        json.dump({"story": story}, temp_file)
        temp_file.write('\n')
        unique_count += 1
    else:
        duplicate_count += 1

    # Periodic garbage collection and progress update
    if i % 10000 == 0 and i > 0:
        gc.collect()
        temp_file.flush()

temp_file.close()

print(f"\n✅ Processing complete:")
print(f"   - Unique stories to recover: {unique_count:,}")
print(f"   - Duplicates skipped: {duplicate_count:,}")

# Clear memory
del current_hashes
gc.collect()
# Out:
# 📝 Finding unique stories from old dataset...
# 💾 Saving unique stories to: /tmp/tmpips1h99q.jsonl
# Processing old dataset: 0it [00:00, ?it/s]
# ✅ Processing complete:
#    - Unique stories to recover: 10,730,620
#    - Duplicates skipped: 0
# 769

# %%
# ===== STEP 7: Load recovered stories from temp file =====
if unique_count > 0:
    print("\n📥 Loading recovered stories from temporary file...")
    recovered_dataset = load_dataset('json', data_files=temp_file.name, split='train')
    print(f"✅ Loaded {len(recovered_dataset):,} recovered stories")

    # Show preview
    print(f"\n   First recovered story (preview):")
    print(f"   {recovered_dataset['story'][0][:150]}...")
else:
    print("\n⚠️ No unique stories to recover")
    recovered_dataset = None
# Out:
# 📥 Loading recovered stories from temporary file...
# Generating train split: 0 examples [00:00, ? examples/s]
# ✅ Loaded 10,730,620 recovered stories
#
#    First recovered story (preview):
#    ත්‍රීවිල් අන්කල්   මම වරකාපොල අපි එහෙට ආවෙ කුලියට. ඉතිං අපි අලුත් හින්දා මෙහෙ අයව දන්නෑ. මම දවසක් ක්ලාස් යනකොට ත්‍රීවිල් එකක් නවත්තලා කිව්වා මල්ලි ටවු...

# %%
# ===== STEP 8: Load current dataset normally for merging =====
if recovered_dataset is not None and len(recovered_dataset) > 0:
    print("\n📥 Loading current dataset for merge...")
    current_dataset = load_dataset(DATASET_REPO, split="train")
    print(f"✅ Current dataset: {len(current_dataset):,} rows")

    # ===== STEP 9: Merge datasets =====
    print("\n🔗 Merging datasets...")
    from datasets import concatenate_datasets

    merged_dataset = concatenate_datasets([current_dataset, recovered_dataset])
    print(f"✅ Merged dataset: {len(merged_dataset):,} rows")

    # Clear memory
    del current_dataset
    del recovered_dataset
    gc.collect()
# Out:
# 📥 Loading current dataset for merge...
# Generating train split:   0%|          | 0/2 [00:00<?, ? examples/s]
# ✅ Current dataset: 2 rows
#
# 🔗 Merging datasets...
# ✅ Merged dataset: 10,730,622 rows

# %%
# ===== STEP 10: Save backup =====
print("\n💾 Saving backup locally...")
merged_dataset.save_to_disk("./merged_dataset_backup")
print("✅ Backup saved")
# Out:
# 💾 Saving backup locally...
# Saving the dataset (0/7 shards):   0%|          | 0/10730622 [00:00<?, ? examples/s]
# ✅ Backup saved

# %%
# ===== STEP 11: Preview =====
print("\n" + "="*60)
print("📊 FINAL DATASET PREVIEW")
print("="*60)
print(f"Total stories: {len(merged_dataset):,}")
print(f"\nFirst story: {merged_dataset['story'][0][:100]}...")
print(f"\nLast story: {merged_dataset['story'][-1][:100]}...")
# Out:
# ============================================================
# 📊 FINAL DATASET PREVIEW
# ============================================================
# Total stories: 10,730,622
#
# First story: මේක දැක්කාම නම් ඕන පිරිමියෙක් පයිය නලලෙ වදින්නම නගිනවා. මටත් දැන් ඉන්නම බෑ පැනල මේක ලෙවකන්නම හිතෙනවා...
#
# Last story: ශෙහාරා – වල් කතා
#
# මේකෙ පුද්ගලයින් 3ක් ඉන්නව. ශෙහාර, නවීන්, දිමුතු.
#
# නවීන් – වයස 36. මේසන් බාස් කෙනෙක...

# %%
# ===== STEP 12: Upload confirmation =====
print("\n" + "="*60)
print("⚠️ READY TO UPLOAD")
print("="*60)

user_input = input("\n⚠️ Upload to Hugging Face? (yes/no): ")

if user_input.lower() in ['yes', 'y']:
    print("\n☁️ Uploading...")
    merged_dataset_dict = DatasetDict({'train': merged_dataset})
    merged_dataset_dict.push_to_hub(
        DATASET_REPO,
        commit_message=f"Recover {unique_count:,} stories from commit {COMMIT_HASH[:7]}"
    )
    print("✅ SUCCESS! Dataset uploaded")
    print(f"🔗 https://huggingface.co/datasets/{DATASET_REPO}")
else:
    print("\n❌ Upload cancelled")
# Out:
# ============================================================
# ⚠️ READY TO UPLOAD
# ============================================================
#
# ⚠️ Upload to Hugging Face? (yes/no): y
#
# ☁️ Uploading...
# Uploading the dataset shards:   0%|          | 0/7 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   9%|8         | 17.8MB /  203MB
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   3%|2         | 5.77MB /  200MB
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   2%|2         | 4.19MB /  201MB
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   2%|2         | 4.72MB /  201MB
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   2%|2         | 4.19MB /  201MB
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :   4%|3         | 7.34MB /  187MB
# Creating parquet from Arrow format:   0%|          | 0/1533 [00:00<?, ?ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#                               :  21%|##        | 33.5MB /  161MB
# ✅ SUCCESS! Dataset uploaded
# 🔗 https://huggingface.co/datasets/Isuru0x01/sinhala_stories

# %%
# ===== Cleanup =====
print("\n🧹 Cleaning up temporary files...")
try:
    os.unlink(temp_file.name)
    print("✅ Temporary files removed")
except:
    pass

print("\n" + "="*60)
print("✅ PROCESS COMPLETE")
print("="*60)
# Out:
# 🧹 Cleaning up temporary files...
# ✅ Temporary files removed
#
# ============================================================
# ✅ PROCESS COMPLETE
# ============================================================
